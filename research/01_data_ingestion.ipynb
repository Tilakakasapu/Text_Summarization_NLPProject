# %%
import os

# %%
# %pwd
# Out:
# 'd:\\CODE\\NLP\\Text_Summarization_NLPProject\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\CODE\\NLP\\Text_Summarization_NLPProject'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from textSummarizer.constants import *
from textSummarizer.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import os 
import urllib.request as request
import zipfile
from textSummarizer.logging import logger
from textSummarizer.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config


    
    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            filename, headers = request.urlretrieve(
                url = self.config.source_URL,
                filename = self.config.local_data_file
            )
            logger.info(f"{filename} download! with following info: \n{headers}")
        else:
            logger.info(f"File already exists of size: {get_size(Path(self.config.local_data_file))}")  

        
    
    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'ascctime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'ascctime'
# Call stack:
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 563, in run_forever
#     self._run_once()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 1844, in _run_once
#     handle._run()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1485882468.py", line 7, in __init__
#     self.config = read_yaml(config_filepath)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "d:\code\nlp\text_summarization_nlpproject\src\textSummarizer\utils\common.py", line 15, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: config\\config.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'ascctime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'ascctime'
# Call stack:
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 563, in run_forever
#     self._run_once()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 1844, in _run_once
#     handle._run()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1485882468.py", line 7, in __init__
#     self.config = read_yaml(config_filepath)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "d:\code\nlp\text_summarization_nlpproject\src\textSummarizer\utils\common.py", line 15, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: config\\config.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'ascctime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'ascctime'
# Call stack:
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 563, in run_forever
#     self._run_once()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 1844, in _run_once
#     handle._run()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1485882468.py", line 8, in __init__
#     self.params = read_yaml(params_filepath)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "d:\code\nlp\text_summarization_nlpproject\src\textSummarizer\utils\common.py", line 15, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: params.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'ascctime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'ascctime'
# Call stack:
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 563, in run_forever
#     self._run_once()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 1844, in _run_once
#     handle._run()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1485882468.py", line 8, in __init__
#     self.params = read_yaml(params_filepath)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ensure\main.py", line 849, in __call__
#     return_val = self.f(*args, **kwargs)
#   File "d:\code\nlp\text_summarization_nlpproject\src\textSummarizer\utils\common.py", line 15, in read_yaml
#     logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# Message: 'yaml file: params.yaml loaded successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'ascctime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'ascctime'
# Call stack:
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 563, in run_forever
#     self._run_once()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 1844, in _run_once
#     handle._run()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1485882468.py", line 10, in __init__
#     create_directories([self.config.artifacts_root])
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "d:\code\nlp\text_summarization_nlpproject\src\textSummarizer\utils\common.py", line 27, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'ascctime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'ascctime'
# Call stack:
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 563, in run_forever
#     self._run_once()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 1844, in _run_once
#     handle._run()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1803582706.py", line 2, in <module>
#     config = ConfigurationManager()
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1485882468.py", line 10, in __init__
#     create_directories([self.config.artifacts_root])
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "d:\code\nlp\text_summarization_nlpproject\src\textSummarizer\utils\common.py", line 27, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'ascctime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'ascctime'
# Call stack:
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 563, in run_forever
#     self._run_once()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 1844, in _run_once
#     handle._run()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1803582706.py", line 3, in <module>
#     data_ingestion_config = config.get_data_ingestion_config()
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1485882468.py", line 17, in get_data_ingestion_config
#     create_directories([config.root_dir])
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "d:\code\nlp\text_summarization_nlpproject\src\textSummarizer\utils\common.py", line 27, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts/data_ingestion'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'ascctime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'ascctime'
# Call stack:
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 563, in run_forever
#     self._run_once()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 1844, in _run_once
#     handle._run()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1803582706.py", line 3, in <module>
#     data_ingestion_config = config.get_data_ingestion_config()
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1485882468.py", line 17, in get_data_ingestion_config
#     create_directories([config.root_dir])
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ensure\main.py", line 807, in __call__
#     return self.f(*args, **kwargs)
#   File "d:\code\nlp\text_summarization_nlpproject\src\textSummarizer\utils\common.py", line 27, in create_directories
#     logger.info(f"created directory at: {path}")
# Message: 'created directory at: artifacts/data_ingestion'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'ascctime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'ascctime'
# Call stack:
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 563, in run_forever
#     self._run_once()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 1844, in _run_once
#     handle._run()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1803582706.py", line 5, in <module>
#     data_ingestion.download_file()
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1434958058.py", line 13, in download_file
#     logger.info(f"{filename} download! with following info: \n{headers}")
# Message: 'artifacts/data_ingestion/data.zip download! with following info: \nConnection: close\nContent-Length: 7903594\nCache-Control: max-age=300\nContent-Security-Policy: default-src \'none\'; style-src \'unsafe-inline\'; sandbox\nContent-Type: application/zip\nETag: "dbc016a060da18070593b83afff580c9b300f0b6ea4147a7988433e04df246ca"\nStrict-Transport-Security: max-age=31536000\nX-Content-Type-Options: nosniff\nX-Frame-Options: deny\nX-XSS-Protection: 1; mode=block\nX-GitHub-Request-Id: 8414:4074:39E932:46FEF9:65B38B8F\nAccept-Ranges: bytes\nDate: Fri, 26 Jan 2024 10:38:09 GMT\nVia: 1.1 varnish\nX-Served-By: cache-maa10227-MAA\nX-Cache: MISS\nX-Cache-Hits: 0\nX-Timer: S1706265489.630748,VS0,VE1341\nVary: Authorization,Accept-Encoding,Origin\nAccess-Control-Allow-Origin: *\nCross-Origin-Resource-Policy: cross-origin\nX-Fastly-Request-ID: 50d2689def8ed6f6ff70d2198b580c988f9dea9d\nExpires: Fri, 26 Jan 2024 10:43:09 GMT\nSource-Age: 1\n\n'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# KeyError: 'ascctime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\logging\__init__.py", line 438, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'ascctime'
# Call stack:
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 192, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 563, in run_forever
#     self._run_once()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\base_events.py", line 1844, in _run_once
#     handle._run()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\tilak\anaconda3\envs\textS\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1803582706.py", line 5, in <module>
#     data_ingestion.download_file()
#   File "C:\Users\tilak\AppData\Local\Temp\ipykernel_23940\1434958058.py", line 13, in download_file
#     logger.info(f"{filename} download! with following info: \n{headers}")
# Message: 'artifacts/data_ingestion/data.zip download! with following info: \nConnection: close\nContent-Length: 7903594\nCache-Control: max-age=300\nContent-Security-Policy: default-src \'none\'; style-src \'unsafe-inline\'; sandbox\nContent-Type: application/zip\nETag: "dbc016a060da18070593b83afff580c9b300f0b6ea4147a7988433e04df246ca"\nStrict-Transport-Security: max-age=31536000\nX-Content-Type-Options: nosniff\nX-Frame-Options: deny\nX-XSS-Protection: 1; mode=block\nX-GitHub-Request-Id: 8414:4074:39E932:46FEF9:65B38B8F\nAccept-Ranges: bytes\nDate: Fri, 26 Jan 2024 10:38:09 GMT\nVia: 1.1 varnish\nX-Served-By: cache-maa10227-MAA\nX-Cache: MISS\nX-Cache-Hits: 0\nX-Timer: S1706265489.630748,VS0,VE1341\nVary: Authorization,Accept-Encoding,Origin\nAccess-Control-Allow-Origin: *\nCross-Origin-Resource-Policy: cross-origin\nX-Fastly-Request-ID: 50d2689def8ed6f6ff70d2198b580c988f9dea9d\nExpires: Fri, 26 Jan 2024 10:43:09 GMT\nSource-Age: 1\n\n'
# Arguments: ()
